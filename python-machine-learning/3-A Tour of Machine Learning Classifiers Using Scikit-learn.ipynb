# %% [markdown]
# #A Tour of Machine Learning Classifiers Using Scikit-learn
# * Introduction to the concepts of popular classification algorithms
#
# * Using the scikit-learn machine learning library
#
# * Questions to ask when selecting a machine learning algorithm

# %% [markdown]
# ## Choosing a classification algorithm

# %% [markdown]
# * 1.Selection of features.
#
# * 2.Choosing a performance metric.
#
# * 3.Choosing a classifier and optimization algorithm.
#
# * 4.Evaluating the performance of the model.
#
# * 5.Tuning the algorithm.

# %% [markdown]
# ### First steps with scikit-learn

# %%
from sklearn import datasets
import numpy as np
iris = datasets.load_iris()
X = iris.data[:,[2,3]]
y = iris.target

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# ####一共有150个样例，训练集有
# $150*0.7=105$个样例

# %%
len(X_train)
# Out:
# 105

# %% [markdown]
# ###拿到训练集首先要进行处理，在scikit-learn中，使用预处理来进行数据处理

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %% [markdown]
# ###使用sckit-learn中的感知机学习算法来进行分类

# %%
from sklearn.linear_model import Perceptron
ppn = Perceptron(n_iter=40, eta0=0.1,random_state=0)
ppn.fit(X_train_std,y_train)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, eta0=0.1, fit_intercept=True,
#       n_iter=40, n_jobs=1, penalty=None, random_state=0, shuffle=False,
#       verbose=0, warm_start=False)

# %% [markdown]
# ####训练已经完成，需要测试一下训练结果怎么样？

# %%
y_pred = ppn.predict(X_test_std)
print 'Misclassified sample: %d' % (y_test != y_pred).sum()
# Out:
# Misclassified sample: 18

# %% [markdown]
# ####Scikit-learn also implements a large variety of different performance metrics that are available via the metrics module. For example, we can calculate the classification accuracy of the perceptron on the test set as follows:

# %%
from sklearn.metrics import accuracy_score
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.60

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ####我们写一个函数，来画图，更加直观显示出训练结果

# %%
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
def plot_decision_regions(X, y, classifier, 
                    test_idx=None, resolution=0.02):
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])
    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                         np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.4, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())
    # plot all samples
    X_test,  y_test  =  X[test_idx,  :],  y[test_idx]                               
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
                    alpha=0.8, c=cmap(idx),
                    marker=markers[idx], label=cl)
    # highlight test samples
    if test_idx:
        X_test, y_test = X[test_idx, :], y[test_idx]   
        plt.scatter(X_test[:, 0], X_test[:, 1], c='', 
                alpha=1.0, linewidth=1, marker='o', 
                s=55, label='test set')

# %%
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))
plot_decision_regions(X=X_combined_std,y=y_combined,classifier=ppn,test_idx=range(105,150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]') 
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ###Modeling class probabilities via logistic regression
#
# ####在我看来，逻辑回归不是一种回归，而是一种分类，根据所判断的概率来进行预测

# %% [markdown]
# for example, the probability that a patient has a certain disease; we can think of the positive event as class label y=1. We can then further define the logit function, which is simply the logarithm of the odds ratio (log-odds):
#
# $logit(p)=\log(\frac{p}{1-p})$

# %% [markdown]
# $logit(p(y=1|x))=w_0x_0+w_1x_1+w_mx_m=\sum_{i=0}^{n}w_mx_m=\omega^Tx$
#
# $\varphi(z)=\frac{1}{1+e^{-z}}$
#
# 下面画出数学公式的图：

# %%
import matplotlib.pyplot as plt
import numpy as np
def sigmoid(z):
    return 1.0 / (1.0 + np.exp(-z))
z = np.arange(-7,7,0.1)
phi_z = sigmoid(z)
plt.plot(z,phi_z)
plt.axvline(0.0,color='k')
plt.axhspan(0.0, 1.0, facecolor='1.0',alpha=1.0, ls='dotted')
plt.axhline(y=0.5,ls='dotted',color='k')
plt.yticks([0.0, 0.5, 1.0])
plt.ylim(-0.1,1.1)
plt.xlabel('z')
plt.ylabel('$\phi (z) $')
plt.show()

# %%
from IPython.display import Image
Image('Propceptron1.png')

# %% [markdown]
# 在实际做的过程中，逻辑回归算法不仅仅是一种分类算法，我们有时候还需要知道发生的概率，因此，这就是逻辑回归比较流行的原因。

# %% [markdown]
# ### Learning the weights of the logistic cost function

# %% [markdown]
# 损失函数为
# $$
# J(w)=\sum_{i}\frac{1}{2}(\varphi(z^{(i)})- y^{(i)})^2
# $$

# %% [markdown]
# 在实际应用中，一般使用对数损失函数开作为损失函数：
#
# $$
#  J(w)=-\sum_{i}y^{(i)}\log(\varphi(z^{(i)})) + (1-y^{(i)})\log(1-\varphi(z^{(i)}))
# $$
#
# ### sklearn.linear_model.LogisticRegression实现了该算法

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(C=1000.0,random_state=0)
lr.fit(X_train_std,y_train)
plot_decision_regions(X_combined_std,y_combined,classifier=lr,test_idx=range(105,150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.show()

# %%
lr.predict_proba(X_test_std[0,:])
# Out:
# array([[  2.05743774e-11,   6.31620264e-02,   9.36837974e-01]])

# %% [markdown]
# ###使用支持向量机算法
# 在前面的线性分类算法中，可以看出该算法效果很差，于是我们使用一段时间很火的一种学习算法--支持向量机

# %%
from sklearn.svm import SVC
svm =SVC(kernel='linear', C=1.0,random_state = 0)

# %%
svm.fit(X_train_std,y_train)
plot_decision_regions(X_combined_std,y_combined,classifier=svm,test_idx = range(105,150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.show()

# %%
y_pred = svm.predict(X_test_std)
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.98

# %% [markdown]
# ####有时候，给我们的数据集特别庞大，于是我们需要另一种算法来加快训练速度.

# %%
from sklearn.linear_model import SGDClassifier
ppn = SGDClassifier(loss='perceptron')

# %% [markdown]
# ###使用支持向量机来解决非线性问题

# %% [markdown]
# 首先我们生成一个非线性可分的可视化数据

# %%
np.random.seed(0)
X_xor = np.random.randn(200,2)

# %%
y_xor = np.logical_xor(X_xor[:,0]>0,X_xor[:,1]>0)
y_xor = np.where(y_xor,1,-1)
plt.scatter(X_xor[y_xor==1,0],X_xor[y_xor==1,1],c='b',marker='x',label='1')
plt.scatter(X_xor[y_xor==-1,0],X_xor[y_xor==-1,1],c='r',marker='s',label='-1')
plt.ylim(-3.0)
plt.legend()
plt.show()

# %%
svm = SVC(kernel='rbf',random_state=0,gamma=0.1,C=10.0)
svm.fit(X_xor,y_xor)
plot_decision_regions(X_xor,y_xor,classifier=svm)
plt.legend(loc='upper left')
plt.show()

# %%
svm = SVC(kernel='rbf',random_state=0,gamma=0.2,C=1.0)
svm.fit(X_train_std,y_train)
plot_decision_regions(X_combined_std,y_combined,classifier=svm,test_idx = range(105,150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.show()

# %%
y_pred = svm.predict(X_test_std)
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.98

# %%
svm = SVC(kernel='rbf',random_state=0,gamma=100,C=1.0)
svm.fit(X_train_std,y_train)
plot_decision_regions(X_combined_std,y_combined,classifier=svm,test_idx = range(105,150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.show()

# %%
y_pred = svm.predict(X_test_std)
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.80

# %% [markdown]
# ###决策树
# Decision tree classifiers are attractive models if we care about interpretability. Like the name decision tree suggests, we can think of this model as breaking down our data by making decisions based on asking a series of questions.

# %%
Image('decision_tree.png')

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(criterion='entropy',max_depth=3, random_state=0)
tree.fit(X_train, y_train)
X_combined = np.vstack((X_train, X_test))
y_combined = np.hstack((y_train, y_test))
plot_decision_regions(X_combined, y_combined,classifier=tree, test_idx=range(105,150))
plt.xlabel('petal length [cm]')
plt.ylabel('petal width [cm]') 
plt.legend(loc='upper left')
plt.show()

# %%
y_pred = tree.predict(X_test)
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.98

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree,out_file='tree.dot',feature_names=['petal length','petal width'])
# Out:
# <open file 'tree.dot', mode 'wb' at 0x000000001375AB70>

# %% [markdown]
# ###随机森林
# Random forests have gained huge popularity in applications of machine learning during the last decade due to their good classification performance, scalability, and ease of use. Intuitively, a random forest can be considered as an ensemble of decision trees. The idea behind ensemble learning is to combine weak learners to build a more robust model, a strong learner, that has a better generalization error and is less susceptible to overfitting. The random forest algorithm can be summarized in four simple steps:
#
# * 1.Draw a random bootstrap sample of size n (randomly choose n samples from the training set with replacement).
#
# * 2.Grow a decision tree from the bootstrap sample. At each node:
#
#   * 1.Randomly select d features without replacement.
#
#   * 2.Split the node using the feature that provides the best split according to the objective function, for instance, by maximizing the information gain.
#
# * 3.Repeat the steps 1 to 2 k times.
#
# * 4.Aggregate the prediction by each tree to assign the class label by majority vote. Majority voting will be discussed in more detail in Chapter 7, Combining Different Models for Ensemble Learning.

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(criterion='entropy',n_estimators=10,random_state=1,n_jobs=2)
forest.fit(X_train, y_train)
plot_decision_regions(X_combined, y_combined,classifier=forest, test_idx=range(105,150))
plt.xlabel('petal length [cm]')
plt.ylabel('petal width [cm]') 
plt.legend(loc='upper left')
plt.show()

# %%
y_pred = forest.predict(X_test)
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.98

# %% [markdown]
# ###K紧邻算法

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5, p=2,metric='minkowski')
knn.fit(X_train_std, y_train)
plot_decision_regions(X_combined_std, y_combined,classifier=knn, test_idx=range(105,150))
plt.xlabel('petal length [cm]')
plt.ylabel('petal width [cm]') 
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ####总结：
# 我们学习了很多的机器学习算法，这些算法都是在scikit-learn中封装好的，因此我们不需要花太多的精力就可以掌握各种算法，下一章我们讲述--构造好的训练集--数据预处理。
