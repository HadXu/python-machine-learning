# %% [markdown]
# #Training Artificial Neural Networks for Image Recognition

# %% [markdown]
# 众所周知，深度学习是当今机器学习毫无疑问的热点，深度学习是以人工神经网络为基础的一种机器学习算法。在这一章中，你将会学习到人工神经网络基本概念，这样你才能够具备知识来探讨更令人兴奋的机器学习领域。
# 这一章将会介绍：
#
# * 理解多层神经网络
#
# * 训练神经网络进行图像识别
#
# * 实现强大的反向传播算法。
#
# * 调试人工神经网络

# %% [markdown]
# ##用人工神经网络建立复杂的模型

# %% [markdown]
# ###Single-layer neural network recap

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# $$
# w:=w+\Delta w , \Delta w = - \eta \nabla J(w)
# $$

# %% [markdown]
# 我们使用最小二乘法来找到最优解，还使用学习速率来求最优解的速度。

# %% [markdown]
# ###Introducing the multi-layer neural network architecture

# %%
from IPython.display import Image

# %%
Image('mlp2.png')

# %%
Image('mlp3Image')

# %% [markdown]
# ###Activating a neural network via forward propagation

# %% [markdown]
# * Starting at the input layer, we forward propagate the patterns of the training data through the network to generate an output.
#
# * Based on the network's output, we calculate the error that we want to minimize using a cost function that we will describe later.
#
# * We backpropagate the error, find its derivative with respect to each weight in the network, and update the model.

# %% [markdown]
# ####现在让我们实例演示一下 分类手写数字识别

# %%
import os
import struct
import numpy as np
def load_mnist(path, kind='train'):
    """Load MNIST data from `path`"""
    labels_path = os.path.join(path, 
                               '%s-labels-idx1-ubyte' 
                                % kind)
    images_path = os.path.join(path, 
                               '%s-images-idx3-ubyte' 
                               % kind)
    with open(labels_path, 'rb') as lbpath:
        magic, n = struct.unpack('>II', 
                                 lbpath.read(8))
        labels = np.fromfile(lbpath, 
                             dtype=np.uint8)
    with open(images_path, 'rb') as imgpath:
        magic, num, rows, cols = struct.unpack(">IIII", 
                                               imgpath.read(16))
        images = np.fromfile(imgpath, 
                    dtype=np.uint8).reshape(len(labels), 784)
    return images, labels

# %%
X_train, y_train = load_mnist('mnist', kind='train')

# %%
X_train.shape[0], X_train.shape[1]
# Out:
# (60000L, 784L)

# %%
X_test, y_test = load_mnist('mnist', kind='t10k')

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, sharex=True, sharey=True,)
ax = ax.flatten()
for i in range(10):
    img = X_train[y_train == i][0].reshape(28, 28)
    ax[i].imshow(img, cmap='Greys', interpolation='nearest')
ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
fig, ax = plt.subplots(nrows=5, ncols=5, sharex=True, sharey=True,)
ax = ax.flatten()
for i in range(25):
    img = X_train[y_train == 8][i].reshape(28, 28)
    ax[i].imshow(img, cmap='Greys', interpolation='nearest')
ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.show()

# %%
np.savetxt('train_img.csv', X_train, fmt='%i', delimiter=',')
np.savetxt('train_labels.csv', y_train, fmt='%i', delimiter=',')
np.savetxt('test_img.csv', X_test, fmt='%i', delimiter=',')
np.savetxt('test_labels.csv', y_test, fmt='%i', delimiter=',')

# %%
X_train = np.genfromtxt('train_img.csv',dtype=int, delimiter=',')
y_train = np.genfromtxt('train_labels.csv',dtype=int, delimiter=',')
X_test = np.genfromtxt('test_img.csv',dtype=int, delimiter=',')
y_test = np.genfromtxt('test_labels.csv',dtype=int, delimiter=',')

# %%
y_train
# Out:
# array([5, 0, 4, ..., 5, 6, 8])

# %% [markdown]
# ###Implementing a multi-layer perceptron

# %% [markdown]
# 现在我们已经知道如何使用人工神经网络算法，接下来我们要慢慢实现人工神经网络算法，首先我们先要理解逻辑损失函数和反向传播算法。

# %% [markdown]
# ###Computing the logistic cost function

# %% [markdown]
# $$
# J(w) = -\sum_{i=1}^{n}{log(a^{(i)})} + (1-y^{(i)})log(1-a^{(i)})
# $$
#
# 需要说明的是，这里的$$a^{(i)}$$是激活函数
# $$
# a^{(i)} = \varphi(z^{(i)})
# $$

# %% [markdown]
# 由于实现一个mlp特别繁琐，于是我就大概介绍一个这个算法，反向传播算法能够更新权重，我们仍然使用披度来进行学习让我们训练模型更快。

# %% [markdown]
# ###总结
# 经过三个星期的努力，终于将一本新书《python machine learning》看完，注意，仅仅是看完，而不是实现玩，尤其是后面关于人工神经网络的部分，仅仅是大概了解了一遍，以后肯定还要花时间来看这一部分内容，作为机器学习的狂热者，我看好深度学习的未来，并乐意在将精力放在深度学习的研究上。
