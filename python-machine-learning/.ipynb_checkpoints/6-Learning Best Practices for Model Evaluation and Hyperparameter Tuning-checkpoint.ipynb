# %% [markdown]
# ##Learning Best Practices for Model Evaluation and Hyperparameter Tuning
# 在前面的章节中，我们学会了如何处理数据，并把他应用在各种算法中。现在，是时候选择好的算法模型。在这一章节中，我们将会学会：
#
# * 获得各个无偏见的计算模型
#
# * 诊断常见的机器学习算法问题
#
# * 改变机器学习算法模型
#
# * 使用各种不同的度量方法来评估将要用于实际模型中
#
#
# ####使用乳腺癌来测试

# %%
import pandas as pd
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data', header=None)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
X = df.loc[:,2:].values
y = df.loc[:,1].values
le = LabelEncoder()
y = le.fit_transform(y)

# %%
le.transform(['M','B'])
# Out:
# array([1, 0], dtype=int64)

# %%
from sklearn.cross_validation import train_test_split

# %%
X_train, X_test, y_train, y_test =train_test_split(X, y, test_size=0.20, random_state=1)

# %% [markdown]
# ####Combining transformers and estimators in a pipeline

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe_lr =Pipeline([('scl',StandardScaler()),
                   ('pca',PCA(n_components=2)),
                   ('clf',LogisticRegression(random_state=1))])

# %%
pipe_lr.fit(X_train,y_train)
print('Test Accuracy: %.3f' % pipe_lr.score(X_test, y_tX_X_train
# Out:
# Test Accuracy: 0.947

# %% [markdown]
# ####Using k-fold cross-validation to assess model performance

# %%
import numpy as np
from sklearn.cross_validation import StratifiedKFold

# %%
kfold = StratifiedKFold(y=y_train,n_folds=10)

# %%
scores = []

# %%
for k, (train, test) in enumerate(kfold):
    pipe_lr.fit(X_train[train], y_train[train])
    score = pipe_lr.score(X_train[test], y_train[test])
    scores.append(score)
    print('Fold: %s, Class dist.: %s, Acc: %.3f' % (k+1,np.bincount(y_train[train]), score))
# Out:
# Fold: 1, Class dist.: [256 153], Acc: 0.978
# Fold: 2, Class dist.: [256 153], Acc: 0.957
# Fold: 3, Class dist.: [256 153], Acc: 0.913
# Fold: 4, Class dist.: [256 153], Acc: 0.957
# Fold: 5, Class dist.: [256 153], Acc: 0.957
# Fold: 6, Class dist.: [257 153], Acc: 0.978
# Fold: 7, Class dist.: [257 153], Acc: 0.911
# Fold: 8, Class dist.: [257 153], Acc: 0.933
# Fold: 9, Class dist.: [257 153], Acc: 0.978
# Fold: 10, Class dist.: [257 153], Acc: 0.933

# %%
print('CV accuracy: %.3f +/- %.3f' % ( np.mean(scores), np.std(scores)))
# Out:
# CV accuracy: 0.949 +/- 0.024

# %% [markdown]
# ##Debugging algorithms with learning and validation curves

# %%
from IPython.display import Image

# %%
Image('confusion_matrix.PNG')

# %% [markdown]
# ##Summary
# 在这一章中，由于涉及很多概念性的知识，我就没有仔细思考。
